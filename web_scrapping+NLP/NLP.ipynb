# %% [markdown]
# # NLP

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
data = pd.read_csv('data_com2.csv', index_col=False, delimiter = ',')
data.head()
# Out:
#    note                                        commentaire
# 0   4.0  une bonne suite pour les aventures de sonic au...
# 1   5.0  Cette suite de sonic est incroyable !Le fan qu...
# 2   4.5  Très bon film ont retrouve ce qui fait l'espri...
# 3   4.0  Super film de ouf, le fait que Knuckles soit d...
# 4   3.0  Malgré deux nouveaux personnages de l'univers ...

# %%
data.isna().sum()
# Out:
# note           0
# commentaire    2
# dtype: int64

# %%
data.dropna(inplace=True)
data.isna().sum()
# Out:
# note           0
# commentaire    0
# dtype: int64

# %%
data.loc[(data.note>3),'sentiment']=1
data.loc[(data.note<=3),'sentiment']=0
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8034 entries, 0 to 8035
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   note         8034 non-null   float64
#  1   commentaire  8034 non-null   object
#  2   sentiment    8034 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 251.1+ KB

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 5))
sns.countplot(x = data.note, data=data, ax=ax[0])
ax[0].set_title("répartition par note")
sns.countplot(x = data.sentiment, data=data, ax=ax[1])
ax[1].set_title("répartition par sentiment")
# Out:
# Text(0.5, 1.0, 'répartition par sentiment')

# %%
pd.crosstab(data.note, data.sentiment, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9de85_row0_col0 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_9de85_row0_col1, #T_9de85_row1_col1, #T_9de85_row2_col1, #T_9de85_row2_col2, #T_9de85_row3_col1, #T_9de85_row4_col1, #T_9de85_row5_col1, #T_9de85_row6_col0, #T_9de85_row7_col0, #T_9de85_row8_col0, #T_9de85_row9_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9de85_row0_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_9de85_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_9de85_row1_col2, #T_9de85_row6_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_9de85_row2_col0 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_9de85_row3_col0 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_9de85_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_9de85_row4_col0 {
#   background-color: #e2f066;
#   color: #000000;
# }
# #T_9de85_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_9de85_row5_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_9de85_row5_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_9de85_row6_col1 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_9de85_row7_col1 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_9de85_row7_col2 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_9de85_row8_col1 {
#   background-color: #cae466;
#   color: #000000;
# }
# #T_9de85_row8_col2 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_9de85_row9_col1 {
#   background-color: #67b366;
#   color: #f1f1f1;
# }
# #T_9de85_row9_col2 {
#   background-color: #91c866;
#   color: #000000;
# }
# #T_9de85_row10_col0, #T_9de85_row10_col1, #T_9de85_row10_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9de85">
#   <thead>
#     <tr>
#       <th class="index_name level0" >sentiment</th>
#       <th id="T_9de85_level0_col0" class="col_heading level0 col0" >0.000000</th>
#       <th id="T_9de85_level0_col1" class="col_heading level0 col1" >1.000000</th>
#       <th id="T_9de85_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >note</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9de85_level0_row0" class="row_heading level0 row0" >0.500000</th>
#       <td id="T_9de85_row0_col0" class="data row0 col0" >780</td>
#       <td id="T_9de85_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9de85_row0_col2" class="data row0 col2" >780</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_9de85_row1_col0" class="data row1 col0" >331</td>
#       <td id="T_9de85_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_9de85_row1_col2" class="data row1 col2" >331</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row2" class="row_heading level0 row2" >1.500000</th>
#       <td id="T_9de85_row2_col0" class="data row2 col0" >121</td>
#       <td id="T_9de85_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_9de85_row2_col2" class="data row2 col2" >121</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row3" class="row_heading level0 row3" >2.000000</th>
#       <td id="T_9de85_row3_col0" class="data row3 col0" >287</td>
#       <td id="T_9de85_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_9de85_row3_col2" class="data row3 col2" >287</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row4" class="row_heading level0 row4" >2.500000</th>
#       <td id="T_9de85_row4_col0" class="data row4 col0" >244</td>
#       <td id="T_9de85_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_9de85_row4_col2" class="data row4 col2" >244</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row5" class="row_heading level0 row5" >3.000000</th>
#       <td id="T_9de85_row5_col0" class="data row5 col0" >358</td>
#       <td id="T_9de85_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_9de85_row5_col2" class="data row5 col2" >358</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row6" class="row_heading level0 row6" >3.500000</th>
#       <td id="T_9de85_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_9de85_row6_col1" class="data row6 col1" >317</td>
#       <td id="T_9de85_row6_col2" class="data row6 col2" >317</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row7" class="row_heading level0 row7" >4.000000</th>
#       <td id="T_9de85_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_9de85_row7_col1" class="data row7 col1" >842</td>
#       <td id="T_9de85_row7_col2" class="data row7 col2" >842</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row8" class="row_heading level0 row8" >4.500000</th>
#       <td id="T_9de85_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_9de85_row8_col1" class="data row8 col1" >1231</td>
#       <td id="T_9de85_row8_col2" class="data row8 col2" >1231</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row9" class="row_heading level0 row9" >5.000000</th>
#       <td id="T_9de85_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_9de85_row9_col1" class="data row9 col1" >3523</td>
#       <td id="T_9de85_row9_col2" class="data row9 col2" >3523</td>
#     </tr>
#     <tr>
#       <th id="T_9de85_level0_row10" class="row_heading level0 row10" >All</th>
#       <td id="T_9de85_row10_col0" class="data row10 col0" >2121</td>
#       <td id="T_9de85_row10_col1" class="data row10 col1" >5913</td>
#       <td id="T_9de85_row10_col2" class="data row10 col2" >8034</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### tokenisation + standardisation

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")
import re

# %%
def standardize_text(donnees):
    '''enlève les nombres, les emoticons, les symboles spéciaux, les adresses http, et met tout en minuscule'''
    emoticon_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    donnees = re.sub(emoticon_pattern, '', donnees)
    donnees = re.sub(r"http\S+", "", donnees)
    donnees = re.sub(r"http", "", donnees)
    donnees = re.sub(r"[?!:..;,/%@()<>=+*'_-]+"," ", donnees)  
    donnees = re.sub(r"[0-9]+", " ", donnees)
    donnees = re.sub(r"\s+", " ", donnees)
    donnees = donnees.lower()
    return donnees

# %%
def tokenize(sentence):
    '''tokenise le commentaire'''
    doc = nlp(sentence)
    return [X.text for X in doc if X.text != " "]

# %%
data['token'] = data.commentaire
i = 0
for sentence in data['token']:
    data_standard = standardize_text(sentence)
    data_token = tokenize(data_standard)
    if data_token != []:
        data.token.values[i] = data_token
    else:
        data.token.values[i] = 'cellule vide'
    i += 1

# %%
# data.token = [standardize_text(com) for com in data.commentaire]
# data.token = [tokenize(com) for com in data.commentaire]
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_2676\3101260134.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.token = [standardize_text(com) for com in data.commentaire]

# %%
data.shape
# Out:
# (8034, 4)

# %%
data.loc[data.token=='cellule vide',:]
# Out:
#       note                                        commentaire  sentiment  \
# 2927   3.0  **********************************************...        0.0
# 3211   0.5  ?????????????????????????!!!!!!!!!!!!!!!!!!!!!...        0.0
# 4073   3.5  .................................................        1.0
#
#              token
# 2927  cellule vide
# 3211  cellule vide
# 4073  cellule vide

# %%
data.drop([data.index[4073]], inplace= True)

# %%
data.drop([data.index[3211]], inplace= True)

# %%
data.drop([data.index[2927]], inplace= True)

# %%
data.shape
# Out:
# (8031, 4)

# %%
data.loc[data.token=='cellule vide',:]
# Out:
# Empty DataFrame
# Columns: [note, commentaire, sentiment, token]
# Index: []

# %% [markdown]
# ## ML

# %%
from sklearn.model_selection import train_test_split

# %%
y = data.sentiment
X = data.token

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)
# Out:
# (6424,) (1607,)

# %% [markdown]
# ### Lemmatisation + stop words

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
liste_stopwords = ['nolan', 'christopher', 'chris', 'dicaprio', 'di caprio', 'leonardo', 'marion', 'cotillard', 'ellen', 'page', 'cillian', 'murphy', 'tom', 'hardy', 'joseph', 'gordon levitt', 'inception',
'sonic', 'knuckles', 'idris', 'elba', 'robotnik', 'jim', 'carrey', 'ibiza', 'Eric', 'Metzger', 'Quentin', 'Margot, Marie-Anne', 'Chazel', 'Stéphane', 'Kazandjian', 'Gérard', 'Darmon', 'Michèle', 'Laroque', 
'Dany', 'Boon', 'Gabriel', 'Aghion', 'Francisco', 'Rabal', 'Xavier', 'Beauvois', 'Marianne', 'Denicourt', 'Bernard', 'Henri','Lévy', 'Jamie' 'Kennedy', 'Alan' 'Cumming', 'Liam', 'Falconer', 'mask', 'Lance', 
'Khazei', 'ibiza', 'Rupert', 'Everett', 'José', 'Garcia', 'Ornella', 'Muti', ' Fabien', 'Onteniente']

# %%
def lemmatizer(X):
    stop_words = set(stopwords.words("french") + liste_stopwords)
    lemmatizer = FrenchLefffLemmatizer()
    for sentence in X:
        mask = X.apply(lambda x:x == sentence)
        i = X[mask].index[0]

        filtered_tokens = [token for token in sentence if token not in stop_words]

        lemmatized_tokens = [lemmatizer.lemmatize(token, 'n') for token in filtered_tokens]
        lemmatized_tokens = [lemmatizer.lemmatize(token, 'v') for token in lemmatized_tokens]
        lemmatized_tokens = [lemmatizer.lemmatize(token, 'a') for token in lemmatized_tokens]
        lemmatized_tokens = [lemmatizer.lemmatize(token, 'r') for token in lemmatized_tokens]

        X[i] = lemmatized_tokens
    return X

# %%
X_train = lemmatizer(X_train)
X_test = lemmatizer(X_test)

# %%
X_train
# Out:
# 3653    [film, inscrire, meilleur, époque, rester, avi...
# 7806    [avoir, celer, ressentir, bien, évidemment, du...
# 7957    [ceux, attendre, passer, bon, moment, rater, f...
# 6126    [beaucoup, apprécier, scénario, vraiment, trav...
# 4797    [tout, simplement, film, époustoufler, scénari...
#                               ...
# 4934    [juste, exceller, tant, scenario, réalisation,...
# 3266    [film, qualité, rester, bluffer, tout, long, t...
# 1653    [vraiment, accrocher, film, sans, queue, ni, t...
# 2607    [impressionner, aller, passer, bon, moment, ha...
# 2732    [assez, compliquer, très, noir, bien, décevoir...
# Name: token, Length: 6424, dtype: object

# %%
import joblib
# model_complet={ "X_train":X_train,
#                 "y_train":y_train,
#                 "X_test":X_test,
#                 "y_test":y_test
#                 }

# joblib.dump(model_complet, 'X_y_token.joblib')
X_train = joblib.load('X_y_token.joblib')['X_train']
y_train = joblib.load('X_y_token.joblib')['y_train']
X_test = joblib.load('X_y_token.joblib')['X_test']
y_test = joblib.load('X_y_token.joblib')['y_test']

# %%
print(y_train.value_counts())
# Out:
# 1.0    4736
# 0.0    1688
# Name: sentiment, dtype: int64

# %%
print(X_train.shape, y_train.shape)
# Out:
# (6424,) (6424,)

# %% [markdown]
# ### Data augmentation - EDA synonym

# %%
from deep_translator import GoogleTranslator
import nlpaug.augmenter.word as naw

# %%
def synonym_aug(sequence): 
   
    sequence_str = ', '.join(sequence)
    aug = naw.SynonymAug(aug_src='wordnet', aug_p=0.2)

    translated = GoogleTranslator(target = 'en').translate(sequence_str)
    augmented_text = aug.augment(translated)
    
    if augmented_text == sequence_str:
        translated_bis = GoogleTranslator(target = 'en').translate(sequence_str)
        augmented_text_bis = aug.augment(translated_bis)

        translated_back_bis = GoogleTranslator(target = 'fr').translate(augmented_text_bis[0])
        return translated_back_bis

    translated_back = GoogleTranslator(target = 'fr').translate(augmented_text[0])    
    return translated_back

# %%
for commentaire in X_train[y_train == 0]:
    com_join = ', '.join(commentaire)
    if len(com_join) < 4800:
        output_translate = synonym_aug(commentaire)  
        com_split = output_translate.split(', ')
        X_train = pd.concat([X_train,pd.Series([com_split], dtype=np.object_)])
        y_train = pd.concat([y_train,pd.Series(0, dtype = np.float64)]) 
    
        print(X_train.shape, y_train.shape)
# Out:
# (6425,) (6425,)
# (6426,) (6426,)
# (6427,) (6427,)
# (6428,) (6428,)
# (6429,) (6429,)
# (6430,) (6430,)
# (6431,) (6431,)
# (6432,) (6432,)
# (6433,) (6433,)
# (6434,) (6434,)
# (6435,) (6435,)
# (6436,) (6436,)
# (6437,) (6437,)
# (6438,) (6438,)
# (6439,) (6439,)
# (6440,) (6440,)
# (6441,) (6441,)
# (6442,) (6442,)
# (6443,) (6443,)
# (6444,) (6444,)
# (6445,) (6445,)
# (6446,) (6446,)
# (6447,) (6447,)
# (6448,) (6448,)
# (6449,) (6449,)
# (6450,) (6450,)
# (6451,) (6451,)
# (6452,) (6452,)
# (6453,) (6453,)
# (6454,) (6454,)
# (6455,) (6455,)
# (6456,) (6456,)
# (6457,) (6457,)
# (6458,) (6458,)
# (6459,) (6459,)
# (6460,) (6460,)
# (6461,) (6461,)
# (6462,) (6462,)
# (6463,) (6463,)
# (6464,) (6464,)
# (6465,) (6465,)
# (6466,) (6466,)
# (6467,) (6467,)
# (6468,) (6468,)
# (6469,) (6469,)
# (6470,) (6470,)
# (6471,) (6471,)
# (6472,) (6472,)
# (6473,) (6473,)
# (6474,) (6474,)
# (6475,) (6475,)
# (6476,) (6476,)
# (6477,) (6477,)
# (6478,) (6478,)
# (6479,) (6479,)
# (6480,) (6480,)
# (6481,) (6481,)
# (6482,) (6482,)
# (6483,) (6483,)
# (6484,) (6484,)
# (6485,) (6485,)
# (6486,) (6486,)
# (6487,) (6487,)
# (6488,) (6488,)
# (6489,) (6489,)
# (6490,) (6490,)
# (6491,) (6491,)
# (6492,) (6492,)
# (6493,) (6493,)
# (6494,) (6494,)
# (6495,) (6495,)
# (6496,) (6496,)
# (6497,) (6497,)
# (6498,) (6498,)
# (8039,) (8039,)
# (8040,) (8040,)
# (8041,) (8041,)
# (8042,) (8042,)
# (8043,) (8043,)
# (8044,) (8044,)
# (8045,) (8045,)
# (8046,) (8046,)
# (8047,) (8047,)
# (8048,) (8048,)
# (8049,) (8049,)
# (8050,) (8050,)
# (8051,) (8051,)
# (8052,) (8052,)
# (8053,) (8053,)
# (8054,) (8054,)
# (8055,) (8055,)
# (8056,) (8056,)
# (8057,) (8057,)
# (8058,) (8058,)
# (8059,) (8059,)
# (8060,) (8060,)
# (8061,) (8061,)
# (8062,) (8062,)
# (8063,) (8063,)
# (8064,) (8064,)
# (8065,) (8065,)
# (8066,) (8066,)
# (8067,) (8067,)
# (8068,) (8068,)
# (8069,) (8069,)
# (8070,) (8070,)
# (8071,) (8071,)
# (8072,) (8072,)
# (8073,) (8073,)
# (8074,) (8074,)
# (8075,) (8075,)
# (8076,) (8076,)
# (8077,) (8077,)
# (8078,) (8078,)
# (8079,) (8079,)
# (8080,) (8080,)
# (8081,) (8081,)
# (8082,) (8082,)
# (8083,) (8083,)
# (8084,) (8084,)
# (8085,) (8085,)
# (8086,) (8086,)
# (8087,) (8087,)
# (8088,) (8088,)
# (8089,) (8089,)
# (8090,) (8090,)
# (8091,) (8091,)
# (8092,) (8092,)
# (8093,) (8093,)
# (8094,) (8094,)
# (8095,) (8095,)
# (8096,) (8096,)
# (8097,) (8097,)
# (8098,) (8098,)
# (8099,) (8099,)
# (8100,) (8100,)
# (8101,) (8101,)
# (8102,) (8102,)
# (8103,) (8103,)
# (8104,) (8104,)
# (8105,) (8105,)
# (8106,) (8106,)
# (8107,) (8107,)
# (8108,) (8108,)
# (8109,) (8109,)
# (8110,) (8110,)
# (8111,) (8111,)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (8111,) (8111,)

# %%
import joblib
# model_complet={ "X_train":X_train,
#                 "y_train":y_train,
#                 "X_test":X_test,
#                 "y_test":y_test
#                 }

# joblib.dump(model_complet, 'X_y_token.joblib')
X_train = joblib.load('X_y_token.joblib')['X_train']
y_train = joblib.load('X_y_token.joblib')['y_train']
X_test = joblib.load('X_y_token.joblib')['X_test']
y_test = joblib.load('X_y_token.joblib')['y_test']

# %% [markdown]
# ### Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
X_train_str = [' '.join(x) for x in X_train]

# %%
text = " ".join(com for com in X_train_str)

stopwords_wc = ['avoir', 'aussi', 'aller', 'inception', 'quand', 'alors', 'alor', 'comme', 'être', 'ça', 'tout', 'déjà', 'cette', 'après', 'bien', 'si', 'là', 'sans', 'car'
'peu', "s'il", 'vous', 'juste', 'où', 'de', 'se', 'la', 'le', 'di', 'à', 'en', 'cela', 'plus', 'lewitt', 'béer', 'garcia', 'du']

wordcloud = WordCloud(stopwords=set(stopwords_wc), max_words=100, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
X_train_neg = [' '.join(x) for x in X_train[y_train== 0]]
X_train_pos = [' '.join(x) for x in X_train[y_train== 1]]

# %%
mots_neg, mots_pos, liste_mots_communs=[],[],[]
for i in X_train_neg:
    neg = i.split()
    mots_neg+=neg
for i in X_train_pos:
    pos = i.split()
    mots_pos+=pos

liste_mots_communs = list(set(mots_neg) & (set(mots_pos)))

# %%
stopwords_mc = stopwords_wc + liste_mots_communs

# %%
text_neg = " ".join(com for com in X_train_neg)

wordcloud_neg = WordCloud(stopwords=set(stopwords_mc), max_words=100, colormap='Reds', mask=np.array(Image.open("dislike.png"))).generate(text_neg)
wordcloud_neg.to_file("pouce_rouge_wc.png")
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
text_pos = " ".join(com for com in X_train_pos)

wordcloud_pos = WordCloud(stopwords=set(stopwords_mc), max_words=100, colormap='summer', mask=np.array(Image.open("like.png"))).generate(text_pos)
wordcloud_pos.to_file("pouce_vert_wc.png")
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ### Data augmentation - création de commentaire

# %%
import random

# %%
mots_neg_list = []
for mot in mots_neg:
    if mot in mots_pos:
        pass
    else:
        mots_neg_list.append(mot)

# %% [markdown]
# Rajout de mots clés pour la création de nouveaux commentaires après vérification qu'ils ne trouvaient pas dans les listes correspondants aux deux cas.

# %%
mots_neg_list += ['daube', 'chier', 'nanar', 'pourri', 'nul', 'navet', 'décevant', 'médiocre', 'débile', 'banal', 'juvénile', 'idiot', 'stupide', 'cliché', 'fade', 'chiant', 'pitoyable']

# %%
mots_pos_list = []
for mot in mots_pos:
    if mot in mots_neg:
        pass
    else:
        mots_pos_list.append(mot)

# %%
mots_neg_list += ['pas mal']

# %%
while y_train.value_counts()[0] < 5000:
    new_com = random.choices(mots_neg_list, k = 200)
    X_train = pd.concat([X_train,pd.Series([new_com], dtype=np.object_)])
    y_train = pd.concat([y_train,pd.Series(0, dtype = np.float64)])

    print(X_train.shape, y_train.shape)
# Out:
# (8112,) (8112,)
# (8113,) (8113,)
# (8114,) (8114,)
# (8115,) (8115,)
# (8116,) (8116,)
# (8117,) (8117,)
# (8118,) (8118,)
# (8119,) (8119,)
# (8120,) (8120,)
# (8121,) (8121,)
# (8122,) (8122,)
# (8123,) (8123,)
# (8124,) (8124,)
# (8125,) (8125,)
# (8126,) (8126,)
# (8127,) (8127,)
# (8128,) (8128,)
# (8129,) (8129,)
# (8130,) (8130,)
# (8131,) (8131,)
# (8132,) (8132,)
# (8133,) (8133,)
# (8134,) (8134,)
# (8135,) (8135,)
# (8136,) (8136,)
# (8137,) (8137,)
# (8138,) (8138,)
# (8139,) (8139,)
# (8140,) (8140,)
# (8141,) (8141,)
# (8142,) (8142,)
# (8143,) (8143,)
# (8144,) (8144,)
# (8145,) (8145,)
# (8146,) (8146,)
# (8147,) (8147,)
# (8148,) (8148,)
# (8149,) (8149,)
# (8150,) (8150,)
# (8151,) (8151,)
# (8152,) (8152,)
# (8153,) (8153,)
# (8154,) (8154,)
# (8155,) (8155,)
# (8156,) (8156,)
# (8157,) (8157,)
# (8158,) (8158,)
# (8159,) (8159,)
# (8160,) (8160,)
# (8161,) (8161,)
# (8162,) (8162,)
# (8163,) (8163,)
# (8164,) (8164,)
# (8165,) (8165,)
# (8166,) (8166,)
# (8167,) (8167,)
# (8168,) (8168,)
# (9709,) (9709,)
# (9710,) (9710,)
# (9711,) (9711,)
# (9712,) (9712,)
# (9713,) (9713,)
# (9714,) (9714,)
# (9715,) (9715,)
# (9716,) (9716,)
# (9717,) (9717,)
# (9718,) (9718,)
# (9719,) (9719,)
# (9720,) (9720,)
# (9721,) (9721,)
# (9722,) (9722,)
# (9723,) (9723,)
# (9724,) (9724,)
# (9725,) (9725,)
# (9726,) (9726,)
# (9727,) (9727,)
# (9728,) (9728,)
# (9729,) (9729,)
# (9730,) (9730,)
# (9731,) (9731,)
# (9732,) (9732,)
# (9733,) (9733,)
# (9734,) (9734,)
# (9735,) (9735,)
# (9736,) (9736,)

# %%
while  y_train.value_counts()[1] < 5000:
    new_com = random.choices(mots_pos_list, k = 200)
    X_train = pd.concat([X_train,pd.Series([new_com], dtype=np.object_)])
    y_train = pd.concat([y_train,pd.Series(1, dtype = np.float64)])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train_vec = [' '.join(x) for x in X_train]
X_test_vec = [' '.join(x) for x in X_test]

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 3))
X_train_vec = vectorizer.fit_transform(X_train_vec)
X_test_vec = vectorizer.transform(X_test_vec)

# %%
# from gensim.models import Word2Vec
# w2v = Word2Vec(X_train, vector_size=100, window=5, min_count=2, workers=4)
# X_train_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_train])
# X_test_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_test])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 3
#       1 from gensim.models import Word2Vec
#       2 w2v = Word2Vec(X_train, vector_size=100, window=5, min_count=2, workers=4)
# ----> 3 X_train_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_train])
#       4 X_test_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_test])
#
# Cell In[112], line 3, in <listcomp>(.0)
#       1 from gensim.models import Word2Vec
#       2 w2v = Word2Vec(X_train, vector_size=100, window=5, min_count=2, workers=4)
# ----> 3 X_train_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_train])
#       4 X_test_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_test])
#
# Cell In[112], line 3, in <listcomp>(.0)
#       1 from gensim.models import Word2Vec
#       2 w2v = Word2Vec(X_train, vector_size=100, window=5, min_count=2, workers=4)
# ----> 3 X_train_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_train])
#       4 X_test_vectors = np.array([np.mean([w2v.wv.__getitem__(word) for word in phrase], axis=0) for phrase in X_test])
#
# File c:\environnement\.venv\lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\environnement\.venv\lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File c:\environnement\.venv\lib\site-packages\gensim\models\keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'angulaire' not present"

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
cv = StratifiedKFold()

# %% [markdown]
# ### LGBMClassifier

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
classifier = lgb.LGBMClassifier()

param_grid= {'boosting_type': ['bgdt', 'dart', 'goss']}
grid = GridSearchCV(classifier, param_grid, cv = cv)
grid.fit(X_train_vec, y_train)
# Out:
# c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 5 fits failed out of a total of 15.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\sklearn.py", line 967, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\sklearn.py", line 748, in fit
#     self._Booster = train(
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\engine.py", line 271, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\basic.py", line 2605, in __init__
#     train_set.construct()
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\basic.py", line 1815, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\basic.py", line 1534, in _lazy_init
#     self.__init_from_csr(data, params_str, ref_dataset)
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\basic.py", line 1728, in __init_from_csr
#     _safe_call(_LIB.LGBM_DatasetCreateFromCSR(
#   File "c:\environnement\.venv\lib\site-packages\lightgbm\basic.py", line 125, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Unknown boosting type bgdt
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [   nan 0.8613 0.8737]
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['bgdt', 'dart', 'goss']})

# %%
grid.best_estimator_
# Out:
# LGBMClassifier(boosting_type='goss')

# %%
grid.best_params_
classifier = grid.best_estimator_
classifier.score(X_test_vec, y_test)
# Out:
# 0.8668326073428749

# %%
y_pred = classifier.predict(X_test_vec)
acc = accuracy_score(y_pred, y_test)
report = classification_report(y_test, y_pred)
print(report)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True)
print("Accuracy of LightGBM Model:", acc*100,"%")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.65      0.72       431
#          1.0       0.88      0.95      0.91      1176
#
#     accuracy                           0.87      1607
#    macro avg       0.85      0.80      0.82      1607
# weighted avg       0.86      0.87      0.86      1607
#
# Accuracy of LightGBM Model: 86.68326073428749 %

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
regressor = LogisticRegression()

# %%
param_grid= {'multi_class':['ovr'],
'random_state': [0],
'penalty': ['l1', 'l2'],
'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}
grid = GridSearchCV(regressor, param_grid, cv = cv)
grid.fit(X_train_vec, y_train)
# Out:
# c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1291, in fit
#     fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#   File "c:\environnement\.venv\lib\site-packages\joblib\parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\environnement\.venv\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\environnement\.venv\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\environnement\.venv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\environnement\.venv\lib\site-packages\joblib\_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "c:\environnement\.venv\lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "c:\environnement\.venv\lib\site-packages\joblib\parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\utils\fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 484, in _logistic_regression_path
#     w0 = sol.solve(X=X, y=target, sample_weight=sample_weight)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_glm\_newton_solver.py", line 372, in solve
#     self.setup(X=X, y=y, sample_weight=sample_weight)
#   File "c:\environnement\.venv\lib\site-packages\sklearn\linear_model\_glm\_newton_solver.py", line 444, in setup
#     self.hessian = np.empty_like(self.coef, shape=(n_dof, n_dof))
#   File "<__array_function__ internals>", line 180, in empty_like
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 10.1 TiB for an array with shape (1180564, 1180564) and data type float64
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\environnement\.venv\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [   nan 0.8395    nan    nan    nan 0.8393 0.8662 0.8662 0.8662    nan
#  0.8662 0.8661]
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(),
#              param_grid={'multi_class': ['ovr'], 'penalty': ['l1', 'l2'],
#                          'random_state': [0],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
grid.best_estimator_
# Out:
# LogisticRegression(multi_class='ovr', random_state=0)

# %%
grid.best_params_
regressor = grid.best_estimator_
regressor.score(X_test_vec, y_test)
# Out:
# 0.8711885500933416

# %%
y_pred_reg = regressor.predict(X_test_vec)

acc_reg = accuracy_score(y_pred_reg, y_test)
print("L'accuaracy score est de :", acc_reg * 100)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# L'accuaracy score est de : 87.11885500933417
# <AxesSubplot: >

# %%
import joblib
# model_complet2={ "X_train":X_train,
#                 "y_train":y_train,
#                 "model_regressor": regressor,
#                 "model_classifier": classifier,
#                 "vectorizer": vectorizer
#                 }

# joblib.dump(model_complet2, 'model_v2.joblib')
vectorizer = joblib.load('model_v2.joblib')['vectorizer']
regressor = joblib.load('model_v2.joblib')['model_regressor']
classifier = joblib.load('model_v2.joblib')['model_classifier']

# %% [markdown]
# ## Essai

# %%
def standardize_phrase(donnees):
        donnees = donnees.replace(r"http\S+", "")
        donnees = donnees.replace(r"http", "")
        donnees = donnees.replace(r"@\S+", "")
        donnees = donnees.replace(r"[0-9(),;!:?@<>.=\'\`\"\-\_\n]", " ")
        donnees = donnees.replace(r"@", "at")
        donnees = donnees.lower()
        
        lemmatizer = FrenchLefffLemmatizer()
        corpus = []
        message = donnees.split()
        message =[word for word in message if word not in stopwords.words('french')]
        message = [lemmatizer.lemmatize(word, 'n') for word in message]
        message = [lemmatizer.lemmatize(word, 'v') for word in message]
        message = [lemmatizer.lemmatize(word, 'a') for word in message]
        message = [lemmatizer.lemmatize(word, 'r') for word in message]
        message = ' '.join(message)
        corpus.append(message)
        
        return corpus

# %%
def test_com_classifier(com):
    com_standard = standardize_phrase(com)
    com_vector = vectorizer.transform(com_standard)
    print('Bien !' if classifier.predict(com_vector)[0] == 1 else 'pas bien !', "Réponse de Classifier")    
    print(classifier.predict_proba(com_vector))

# %%
def test_com_regressor(com):
    com_standard = standardize_phrase(com)
    com_vector = vectorizer.transform(com_standard)
    print('Bien !' if regressor.predict(com_vector)[0] == 1 else 'pas bien !', "Réponse de Regressor")    
    print(regressor.predict_proba(com_vector))

# %%
test = "Ce film est vraiment pas mal !"
test_com_classifier(test)
test_com_regressor(test)
# Out:
# Bien ! Réponse de Classifier
# [[0.4244304 0.5755696]]
# Bien ! Réponse de Regressor
# [[0.47220609 0.52779391]]

# %% [markdown]
# - 13/01/23 11:30 - Sans data augmentation ou équilibrage des deux classes et TfidfVectorizer + LGBMClassifier(utiliser dans le tuto), le résultat est de 87% !
# - 13/01/23 13:40 - Même paramètre qu'au dessus, mais avec suppression des mots en commun entre les com + et -. Le model chutte à 80% ! à avoir si je garde ou non !
# - 13/01/23 14:00 - Toujours sans data augmentation et sans équilibrage + model logisticRegression + mot en commun => 80%
# - 13/01/23 14:20 - idem que précédemment, mais sans mot en commun => 84%
# - 13/01/23 22:00 - data augmentation par back translation (qq prob pour le mettre en place et qui n'a pas finit, encore une erreur au bout de 45 min, début traduction allemand) => LGBMClassifier = 87% et logisticRegression = 89%
# - 14/01/23 11:00 - data augmentation par back translation (après une 1h40, toujours pas finit, je stoppe avant, 4700 + pour 4200 -) => LGBMClassifier = 87% et logisticRegression = 89% (même résultat qu'hier !)
# - 14/01/23 14:20 - data augmentation par back translation + synonym => LGBMClassifier = 87% et logisticRegression = 90% (arrondi à 0.1)
# - 14/01/23 17:40 - data augmentation par back translation + synonym + création nouvelle phrase à partir des mots présents dans les com + et - => LGBMClassifier = 87.04% et logisticRegression = 90.09%
# - 15/01/23 07:40 - ajout de commentaire neg + étapes précédente => LGBMClassifier = 87.5% et logisticRegression = 89.3%
# - 15/01/22 08:10 - recherche des meilleurs hyper-paramètres => LGBMClassifier = 86.99% et logisticRegression = 89.3%
# - 19/01/22 16:15 - ajoute des éléments à lemmatiser => LGBMClassifier = 87.3% et logisticRegression = 89.79%

# %% [markdown]
# - 17/01/23 20:00 - v2 => mis en place des tokens sans data augmentation => LGBMClassifier = 86.9% et logisticRegression = 86.6%
# - 18/01/23 11:30 - data augmentation par back translation synonym => LGBMClassifier = 85.8% et logisticRegression = 84.49%
# - 18/01/23 18:45 - data augmentation augmenté avec des créations de commentaires et des mots clés rajoutés au mot négatif => LGBMClassifier = 85.7% et logisticRegression = 86.6%
# - 18/01/23 18:45 - data augmentation augmenté avec des créations de commentaires pour atteindre 5000 dans les deux catégories => LGBMClassifier = 86.2% et logisticRegression = 86.5%
# - 19/01/23 14:00 - idem, mais en rajoutant des éléments à lemmatiser => LGBMClassifier = 86.6% et logisticRegression = 87.1%
